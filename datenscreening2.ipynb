# %%
import mariadb #DB Handling
import plotly #plotting #1
import pandas as pd #Dataframes
import matplotlib as plt #plotting #2

import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
def connection_and_cursor(user="bi2021", password="businessintelligence", host="212.201.138.114", port=3306, database="homeassistant"):
    conn = mariadb.connect(
        user=user,
        password=password,
        host=host,
        port=port,
        database=database # only interesting database
    )

    cur = conn.cursor()

    return conn, cur

conn, cur = connection_and_cursor()

# %%
def initial_df(cur):
    cur.execute("show columns from states")

    cols = []

    for i in cur:
        cols.append(i[0])

    print("Spalten in Columns:", cols) # all columns in states

    cur.execute("SELECT * FROM states")
    df = pd.DataFrame(data=cur.fetchall(), columns=cols)
    print(df.info())
    
    return df

df = initial_df(cur)
# Out:
# Spalten in Columns: ['state_id', 'domain', 'entity_id', 'state', 'attributes', 'event_id', 'last_changed', 'last_updated', 'created', 'old_state_id']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628188 entries, 0 to 628187
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   state_id      628188 non-null  int64
#  1   domain        628188 non-null  object
#  2   entity_id     628188 non-null  object
#  3   state         628187 non-null  object
#  4   attributes    628188 non-null  object
#  5   event_id      628188 non-null  int64
#  6   last_changed  628188 non-null  datetime64[ns]
#  7   last_updated  628188 non-null  datetime64[ns]
#  8   created       628188 non-null  datetime64[ns]
#  9   old_state_id  627907 non-null  float64
# dtypes: datetime64[ns](3), float64(1), int64(2), object(4)
# memory usage: 47.9+ MB
# None

# %%
def drop_non_relevant(df):
    print("dropped", len(df[df["entity_id"]=="person.fschmidmichels"]), "from 'person.fschmidmichels'")
    df = df.drop(df[df["entity_id"]=="person.fschmidmichels"].index, 0)
    print("dropped", len(df[df["entity_id"]=="weather.langer_weg"]), "from 'weather.langer_weg'")
    df = df.drop(df[df["entity_id"]=="weather.langer_weg"].index, 0)
    print("dropped", len(df[df["entity_id"]=="zone.home"]), "from 'zone.home'")
    df = df.drop(df[df["entity_id"]=="zone.home"].index, 0)
    print("dropped", len(df[df["entity_id"]=="print_entities_to_file"]), "from 'print_entities_to_file'")
    df = df.drop(df[df["entity_id"]=="script.print_entities_to_file"].index, 0)
    print("dropped", len(df[df["entity_id"]=="wlan_switch_energy_totalstarttime"]), "from 'wlan_switch_energy_totalstarttime'")
    df = df.drop(df[df["entity_id"]=="sensor.wlan_switch_energy_totalstarttime"].index, 0)
    print("dropped", len(df[df["entity_id"]=="wlan_switch_status"]), "from 'wlan_switch_status'")
    df = df.drop(df[df["entity_id"]=="sensor.wlan_switch_status"].index, 0)
    print("dropped", len(df[df["entity_id"]=="switch.smartplug3_230v"]), "from 'switch.smartplug3_230v'")
    df = df.drop(df[df["entity_id"]=="switch.smartplug3_230v"].index, 0)
    print("dropped", len(df[df["entity_id"]=="sensor.smartplug3_energy_totalstarttime"]), "from 'sensor.smartplug3_energy_totalstarttime'")
    df = df.drop(df[df["entity_id"]=="sensor.smartplug3_energy_totalstarttime"].index, 0)
    print("dropped", len(df[df["entity_id"]=="sensor.smartplug3_status"]), "from 'sensor.smartplug3_status'")
    df = df.drop(df[df["entity_id"]=="sensor.smartplug3_status"].index, 0)
    print("dropped", len(df[df["entity_id"]=="switch.smartplug3_usb"]), "from 'switch.smartplug3_usb'")
    df = df.drop(df[df["entity_id"]=="switch.smartplug3_usb"].index, 0)
    print("dropped", len(df[df["entity_id"]=="sun.sun"]), "from 'sun.sun'")
    df = df.drop(df[df["entity_id"]=="sun.sun"].index, 0)
    print("dropped", len(df[df["entity_id"]=="binary_sensor.updater"]), "from 'binary_sensor.updater'")
    df = df.drop(df[df["entity_id"]=="binary_sensor.updater"].index, 0)
    
    ######from here on in excel unmentioned entityids######

    print("dropped", len(df[df["entity_id"]=="binary_sensor.wlan_switch_button1"]), "from 'binary_sensor.wlan_switch_button1'")
    df = df.drop(df[df["entity_id"]=="binary_sensor.wlan_switch_button1"].index, 0)
    print("dropped", len(df[df["entity_id"]=="persistent_notification.config_entry_discovery"]), "from 'persistent_notification.config_entry_discovery'")
    df = df.drop(df[df["entity_id"]=="persistent_notification.config_entry_discovery"].index, 0)
    print("dropped", len(df[df["entity_id"]=="sensor.mh_z19_temperature"]), "from 'sensor.mh_z19_temperature'")
    df = df.drop(df[df["entity_id"]=="sensor.mh_z19_temperature"].index, 0)
    print("dropped", len(df[df["entity_id"]=="switch.wlan_switch"]), "from 'switch.wlan_switch'")
    df = df.drop(df[df["entity_id"]=="switch.wlan_switch"].index, 0)

    return df

df = drop_non_relevant(df)
# Out:
# dropped 6 from 'person.fschmidmichels'
# dropped 913 from 'weather.langer_weg'
# dropped 3 from 'zone.home'
# dropped 0 from 'print_entities_to_file'
# dropped 0 from 'wlan_switch_energy_totalstarttime'
# dropped 0 from 'wlan_switch_status'
# dropped 12 from 'switch.smartplug3_230v'
# dropped 11031 from 'sensor.smartplug3_energy_totalstarttime'
# dropped 13732 from 'sensor.smartplug3_status'
# dropped 14 from 'switch.smartplug3_usb'
# dropped 9596 from 'sun.sun'
# dropped 12 from 'binary_sensor.updater'
# dropped 5 from 'binary_sensor.wlan_switch_button1'
# dropped 2 from 'persistent_notification.config_entry_discovery'
# dropped 2045 from 'sensor.mh_z19_temperature'
# dropped 7 from 'switch.wlan_switch'

# %%
def make_df_dict(df):
    df_dict = {}
    for i in df["entity_id"].unique():
        print("convert to df_dict: entity_id:", i)
        #print("...", df[df["entity_id"]==str(i)])
        df_dict.update({i:df[df["entity_id"]==str(i)]})
    
    return df_dict

df_dict = make_df_dict(df)
# Out:
# convert to df_dict: entity_id: sensor.sensor_2_uptime
# convert to df_dict: entity_id: sensor.mh_z19_co2_value
# convert to df_dict: entity_id: sensor.sensor_3_uptime
# convert to df_dict: entity_id: sensor.sensor_1_wifi_signal
# convert to df_dict: entity_id: sensor.sensor_1_uptime
# convert to df_dict: entity_id: sensor.sensor_3_wifi_signal
# convert to df_dict: entity_id: sensor.sensor_2_wifi_signal
# convert to df_dict: entity_id: sensor.bme280_temperature
# convert to df_dict: entity_id: sensor.dht22_temperature
# convert to df_dict: entity_id: sensor.dht22_humidity
# convert to df_dict: entity_id: sensor.bme280_pressure
# convert to df_dict: entity_id: sensor.smartplug3_energy_total
# convert to df_dict: entity_id: sensor.smartplug3_energy_yesterday
# convert to df_dict: entity_id: sensor.smartplug3_energy_today
# convert to df_dict: entity_id: sensor.smartplug3_energy_power
# convert to df_dict: entity_id: sensor.smartplug3_energy_apparentpower
# convert to df_dict: entity_id: sensor.smartplug3_energy_reactivepower
# convert to df_dict: entity_id: sensor.smartplug3_energy_voltage
# convert to df_dict: entity_id: sensor.smartplug3_energy_factor
# convert to df_dict: entity_id: sensor.smartplug3_energy_current
# convert to df_dict: entity_id: sensor.ccs811_eco2_value
# convert to df_dict: entity_id: sensor.ccs811_total_volatile_organic_compound
# convert to df_dict: entity_id: sensor.bme280_humidity
# convert to df_dict: entity_id: sensor.bh1750_illuminance_2
# convert to df_dict: entity_id: sensor.bh1750_illuminance
# convert to df_dict: entity_id: binary_sensor.sensor_2_sensor_status
# convert to df_dict: entity_id: sensor.sensor_2_firmware_version
# convert to df_dict: entity_id: binary_sensor.sensor_1_sensor_status
# convert to df_dict: entity_id: sensor.sensor_1_firmware_version
# convert to df_dict: entity_id: binary_sensor.sensor_3_sensor_status
# convert to df_dict: entity_id: sensor.sensor_3_firmware_version
# convert to df_dict: entity_id: sensor.wlan_switch_energy_total
# convert to df_dict: entity_id: sensor.wlan_switch_energy_yesterday
# convert to df_dict: entity_id: sensor.wlan_switch_energy_today
# convert to df_dict: entity_id: sensor.wlan_switch_energy_power
# convert to df_dict: entity_id: sensor.wlan_switch_energy_apparentpower
# convert to df_dict: entity_id: sensor.wlan_switch_energy_reactivepower
# convert to df_dict: entity_id: sensor.wlan_switch_energy_factor
# convert to df_dict: entity_id: sensor.wlan_switch_energy_voltage
# convert to df_dict: entity_id: sensor.wlan_switch_energy_current

# %%
def convert_and_delete (df_dict):
    list_nonnum = []
    for i in df_dict:
        print("Aktuelle entity_id:", i)
        print(df_dict[i]["state"].head(), "\n")
        print("Anzahl unknown: ", df_dict[i][df_dict[i]["state"]=="unknown"].count())
        print("Anzahl unavailable: ", df_dict[i][df_dict[i]["state"]=="unavailable"].count())
        df_dict[i] = df_dict[i].drop(df_dict[i][df_dict[i]["state"]=="unknown"].index)
        df_dict[i] = df_dict[i].drop(df_dict[i][df_dict[i]["state"]=="unavailable"].index)

        try:             
            df_dict[i]["state"] = pd.to_numeric(df_dict[i]["state"])
            print(i, "Erfolgreich zu numerischen Werten konvertiert")

        except:
            print("Nicht numerisch: ", i)
            list_nonnum.append(str(i))
    #print(list_nonnum)
    for i in list_nonnum:
        try:
            df_dict[i].state.apply(str)
            list_nonnum.remove(i)
        except:
            print("non numeric nor string:", i)

        #print(df_dict[i]["state"].head(), "\n")
    print("Weder numerisch noch String:", list_nonnum)

    return df_dict

df_dict = convert_and_delete(df_dict)
# Out:
# Aktuelle entity_id: sensor.sensor_2_uptime
# 0     1537677
# 7     1537737
# 14    1537797
# 21    1537857
# 30    1537917
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.sensor_2_uptime Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.mh_z19_co2_value
# 1     401
# 8     403
# 15    404
# 23    403
# 34    400
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.mh_z19_co2_value Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.sensor_3_uptime
# 2     1537726
# 9     1537786
# 16    1537846
# 24    1537906
# 35    1537966
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.sensor_3_uptime Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.sensor_1_wifi_signal
# 3     -43
# 10    -42
# 17    -45
# 74    -42
# 93    -41
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    5
# dtype: int64
# sensor.sensor_1_wifi_signal Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.sensor_1_uptime
# 4     1537733
# 11    1537793
# 18    1537853
# 27    1537913
# 36    1537973
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    5
# dtype: int64
# sensor.sensor_1_uptime Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.sensor_3_wifi_signal
# 5     -20
# 12    -21
# 19    -28
# 28    -27
# 51    -26
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.sensor_3_wifi_signal Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.sensor_2_wifi_signal
# 6     -48
# 13    -47
# 20    -49
# 29    -48
# 63    -47
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.sensor_2_wifi_signal Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.bme280_temperature
# 22     26.0
# 32     25.9
# 225    26.0
# 233    25.9
# 406    26.0
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    5
# dtype: int64
# sensor.bme280_temperature Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.dht22_temperature
# 25     26.0
# 73     26.3
# 92     26.0
# 162    26.1
# 188    26.0
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.dht22_temperature Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.dht22_humidity
# 26     37
# 476    36
# 498    37
# 537    36
# 547    37
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.dht22_humidity Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.bme280_pressure
# 33     1017.4
# 117    1017.3
# 133    1017.4
# 146    1017.3
# 152    1017.4
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    5
# dtype: int64
# sensor.bme280_pressure Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_total
# 38     21.044
# 78     21.044
# 121    21.044
# 166    21.045
# 213    21.045
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        29
# domain          29
# entity_id       29
# state           29
# attributes      29
# event_id        29
# last_changed    29
# last_updated    29
# created         29
# old_state_id    27
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_total Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_yesterday
# 39     0.039
# 79     0.039
# 122    0.039
# 167    0.039
# 214    0.039
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        29
# domain          29
# entity_id       29
# state           29
# attributes      29
# event_id        29
# last_changed    29
# last_updated    29
# created         29
# old_state_id    27
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_yesterday Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_today
# 40     0.008
# 80     0.009
# 123    0.009
# 168    0.009
# 215    0.009
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        28
# domain          28
# entity_id       28
# state           28
# attributes      28
# event_id        28
# last_changed    28
# last_updated    28
# created         28
# old_state_id    26
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_today Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_power
# 41     2
# 81     2
# 124    2
# 169    2
# 216    2
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        27
# domain          27
# entity_id       27
# state           27
# attributes      27
# event_id        27
# last_changed    27
# last_updated    27
# created         27
# old_state_id    25
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_power Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_apparentpower
# 42     12
# 82     12
# 125    13
# 170    11
# 217    13
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        27
# domain          27
# entity_id       27
# state           27
# attributes      27
# event_id        27
# last_changed    27
# last_updated    27
# created         27
# old_state_id    25
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_apparentpower Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_reactivepower
# 43     12
# 83     12
# 126    13
# 171    11
# 218    13
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_reactivepower Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_voltage
# 44     233
# 84     233
# 127    233
# 172    232
# 219    232
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        25
# domain          25
# entity_id       25
# state           25
# attributes      25
# event_id        25
# last_changed    25
# last_updated    25
# created         25
# old_state_id    23
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_voltage Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_factor
# 45     0.13
# 85     0.14
# 128    0.13
# 173    0.16
# 220    0.14
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        25
# domain          25
# entity_id       25
# state           25
# attributes      25
# event_id        25
# last_changed    25
# last_updated    25
# created         25
# old_state_id    23
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_factor Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.smartplug3_energy_current
# 46     0.053
# 86      0.05
# 129    0.056
# 174    0.049
# 221    0.056
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        24
# domain          24
# entity_id       24
# state           24
# attributes      24
# event_id        24
# last_changed    24
# last_updated    24
# created         24
# old_state_id    22
# dtype: int64
# Anzahl unavailable:  state_id        5
# domain          5
# entity_id       5
# state           5
# attributes      5
# event_id        5
# last_changed    5
# last_updated    5
# created         5
# old_state_id    4
# dtype: int64
# sensor.smartplug3_energy_current Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.ccs811_eco2_value
# 56     413
# 87     406
# 130    403
# 138    406
# 175    413
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.ccs811_eco2_value Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.ccs811_total_volatile_organic_compound
# 57     1
# 88     0
# 176    1
# 184    0
# 203    1
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.ccs811_total_volatile_organic_compound Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.bme280_humidity
# 678     32.0
# 773     31.9
# 1139    32.0
# 1278    32.1
# 1290    32.0
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    5
# dtype: int64
# sensor.bme280_humidity Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.bh1750_illuminance_2
# 949     0.8
# 977     1.7
# 990     2.5
# 999     3.3
# 1017    4.2
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     7
# dtype: int64
# sensor.bh1750_illuminance_2 Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.bh1750_illuminance
# 1291    0.8
# 1337    1.7
# 1378    2.5
# 1396    3.3
# 1430    4.2
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    5
# dtype: int64
# sensor.bh1750_illuminance Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: binary_sensor.sensor_2_sensor_status
# 22504    off
# 22527     on
# 97828    off
# 97851     on
# 99743    off
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Nicht numerisch:  binary_sensor.sensor_2_sensor_status
# Aktuelle entity_id: sensor.sensor_2_firmware_version
# 22508                     unavailable
# 22534    1.15.3 Nov  9 2020, 09:57:38
# 97832                     unavailable
# 97859    1.15.3 Nov  9 2020, 09:57:38
# 99747                     unavailable
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     5
# dtype: int64
# Nicht numerisch:  sensor.sensor_2_firmware_version
# Aktuelle entity_id: binary_sensor.sensor_1_sensor_status
# 22509    off
# 22530     on
# 63984    off
# 64002     on
# 97843    off
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Nicht numerisch:  binary_sensor.sensor_1_sensor_status
# Aktuelle entity_id: sensor.sensor_1_firmware_version
# 22516                     unavailable
# 22545    1.15.3 Nov  9 2020, 11:04:07
# 63991                     unavailable
# 64010    1.15.3 Nov  9 2020, 11:04:07
# 97850                     unavailable
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        8
# domain          8
# entity_id       8
# state           8
# attributes      8
# event_id        8
# last_changed    8
# last_updated    8
# created         8
# old_state_id    3
# dtype: int64
# Nicht numerisch:  sensor.sensor_1_firmware_version
# Aktuelle entity_id: binary_sensor.sensor_3_sensor_status
# 22517    off
# 22533     on
# 63992    off
# 64003     on
# 97833    off
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Nicht numerisch:  binary_sensor.sensor_3_sensor_status
# Aktuelle entity_id: sensor.sensor_3_firmware_version
# 22526                       unavailable
# 22549    2021.8.2 Sep 15 2021, 12:17:52
# 64001                       unavailable
# 64019    2021.8.2 Sep 15 2021, 12:17:52
# 97842                       unavailable
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# Anzahl unavailable:  state_id        10
# domain          10
# entity_id       10
# state           10
# attributes      10
# event_id        10
# last_changed    10
# last_updated    10
# created         10
# old_state_id     5
# dtype: int64
# Nicht numerisch:  sensor.sensor_3_firmware_version
# Aktuelle entity_id: sensor.wlan_switch_energy_total
# 100700    unknown
# 100711    unknown
# 100722    unknown
# 100733    unknown
# 100744    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        27
# domain          27
# entity_id       27
# state           27
# attributes      27
# event_id        27
# last_changed    27
# last_updated    27
# created         27
# old_state_id    25
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_total Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_yesterday
# 100701    unknown
# 100712    unknown
# 100723    unknown
# 100734    unknown
# 100745    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        27
# domain          27
# entity_id       27
# state           27
# attributes      27
# event_id        27
# last_changed    27
# last_updated    27
# created         27
# old_state_id    25
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_yesterday Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_today
# 100702    unknown
# 100713    unknown
# 100724    unknown
# 100735    unknown
# 100746    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_today Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_power
# 100703    unknown
# 100714    unknown
# 100725    unknown
# 100736    unknown
# 100747    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_power Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_apparentpower
# 100704    unknown
# 100715    unknown
# 100726    unknown
# 100737    unknown
# 100748    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_apparentpower Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_reactivepower
# 100705    unknown
# 100716    unknown
# 100727    unknown
# 100738    unknown
# 100749    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_reactivepower Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_factor
# 100706    unknown
# 100717    unknown
# 100728    unknown
# 100739    unknown
# 100750    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_factor Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_voltage
# 100707    unknown
# 100718    unknown
# 100729    unknown
# 100740    unknown
# 100751    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        26
# domain          26
# entity_id       26
# state           26
# attributes      26
# event_id        26
# last_changed    26
# last_updated    26
# created         26
# old_state_id    24
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_voltage Erfolgreich zu numerischen Werten konvertiert
# Aktuelle entity_id: sensor.wlan_switch_energy_current
# 100708    unknown
# 100719    unknown
# 100730    unknown
# 100741    unknown
# 100752    unknown
# Name: state, dtype: object
#
# Anzahl unknown:  state_id        25
# domain          25
# entity_id       25
# state           25
# attributes      25
# event_id        25
# last_changed    25
# last_updated    25
# created         25
# old_state_id    23
# dtype: int64
# Anzahl unavailable:  state_id        0
# domain          0
# entity_id       0
# state           0
# attributes      0
# event_id        0
# last_changed    0
# last_updated    0
# created         0
# old_state_id    0
# dtype: int64
# sensor.wlan_switch_energy_current Erfolgreich zu numerischen Werten konvertiert
# Weder numerisch noch String: ['sensor.sensor_2_firmware_version', 'sensor.sensor_1_firmware_version', 'sensor.sensor_3_firmware_version']

# %%
def close_conn(conn):
    conn.close()

close_conn(conn)
